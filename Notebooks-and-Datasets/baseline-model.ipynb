# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("gurgaon_properties_post_feature_selection.csv")

# %%
df.head()
# Out:
#    property_type  sector  bedRoom  bathroom  balcony  floorNum  agePossession  \
# 0            0.0    36.0      3.0       2.0      2.0       1.0            1.0
# 1            0.0    95.0      2.0       2.0      2.0       2.0            1.0
# 2            0.0   103.0      2.0       2.0      1.0       0.0            1.0
# 3            0.0    99.0      3.0       4.0      4.0       2.0            3.0
# 4            0.0     5.0      2.0       2.0      1.0       2.0            3.0
#
#    built_up_area  servant room  store room  furnishing_type  luxury_score  \
# 0          850.0           0.0         0.0              0.0           1.0
# 1         1226.0           1.0         0.0              0.0           1.0
# 2         1000.0           0.0         0.0              0.0           1.0
# 3         1615.0           1.0         0.0              1.0           0.0
# 4          582.0           0.0         1.0              0.0           0.0
#
#    price
# 0   0.82
# 1   0.95
# 2   0.32
# 3   1.60
# 4   0.48

# %%
col_ohe=["property_type","sector","agePossession","furnishing_type","luxury_score","floorNum"]

# %%
df[col_ohe]
# Out:
#       property_type  sector  agePossession  furnishing_type  luxury_score  \
# 0               0.0    36.0            1.0              0.0           1.0
# 1               0.0    95.0            1.0              0.0           1.0
# 2               0.0   103.0            1.0              0.0           1.0
# 3               0.0    99.0            3.0              1.0           0.0
# 4               0.0     5.0            3.0              0.0           0.0
# ...             ...     ...            ...              ...           ...
# 3549            0.0    90.0            3.0              0.0           2.0
# 3550            1.0    12.0            3.0              0.0           0.0
# 3551            0.0    23.0            0.0              1.0           2.0
# 3552            1.0    44.0            0.0              0.0           2.0
# 3553            0.0    71.0            3.0              1.0           2.0
#
#       floorNum
# 0          1.0
# 1          2.0
# 2          0.0
# 3          2.0
# 4          2.0
# ...        ...
# 3549       2.0
# 3550       1.0
# 3551       2.0
# 3552       2.0
# 3553       0.0
#
# [3554 rows x 6 columns]

# %%
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.model_selection import KFold,cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR

# %%
X=df.drop("price",axis=1)

# %%
X.head(3)
# Out:
#    property_type  sector  bedRoom  bathroom  balcony  floorNum  agePossession  \
# 0            0.0    36.0      3.0       2.0      2.0       1.0            1.0
# 1            0.0    95.0      2.0       2.0      2.0       2.0            1.0
# 2            0.0   103.0      2.0       2.0      1.0       0.0            1.0
#
#    built_up_area  servant room  store room  furnishing_type  luxury_score
# 0          850.0           0.0         0.0              0.0           1.0
# 1         1226.0           1.0         0.0              0.0           1.0
# 2         1000.0           0.0         0.0              0.0           1.0

# %%
y=df["price"]
y.head(2)
# Out:
# 0    0.82
# 1    0.95
# Name: price, dtype: float64

# %%
y_transformed=np.log1p(y)

# %%
# Creating a column transformer for preprocessing

preprocessor=ColumnTransformer(
    transformers=[
        ('num',StandardScaler(),['bedRoom', 'bathroom', 'built_up_area', 'servant room', 'store room']),
        ('cat',OneHotEncoder(),col_ohe)
    ],
    remainder='passthrough'
)

# %%
svr=SVR(kernel='rbf')

# %%
#creating a pipeline
pipeline=Pipeline([
    ('preprocessor',preprocessor),
    ('regressor',svr)
]
)

# %%
# K-fold cross-validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)
scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')

# %%
scores.mean()
# Out:
# 0.8842548911061348

# %%
scores.std()
# Out:
# 0.014655824854239748

# %%
#the r2 score is good in base model , but we cant rely on only r2 score

# %%
#calculate MAE

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)

# %%
pipeline.fit(X_train,y_train)
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\compose\_column_transformer.py:1623: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['bedRoom', 'bathroom',
#                                                    'built_up_area',
#                                                    'servant room',
#                                                    'store room']),
#                                                  ('cat', OneHotEncoder(),
#                                                   ['property_type', 'sector',
#                                                    'agePossession',
#                                                    'furnishing_type',
#                                                    'luxury_score',
#                                                    'floorNum'])])),
#                 ('regressor', SVR())])

# %%
y_pred=pipeline.predict(X_test)

# %%
y_pred = np.expm1(y_pred)

# %%
mean_absolute_error(np.expm1(y_test),y_pred)
# Out:
# 0.522409997980398

# %%
#although our r2 score is good , but this MAE shows how icorrect and unreliable prediction can be done by our model
