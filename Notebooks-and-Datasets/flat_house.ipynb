# %%
import numpy as np
import pandas as pd

# %%
pd.set_option("display.max_rows",None)
pd.set_option("display.max_columns",None)

# %%
flats=pd.read_csv("flats_cleaned.csv")
house=pd.read_csv("house_cleaned.csv")

# %%
flats.head(3)
# Out:
#                   property_name property_type                 society  price  \
# 0  2 BHK Flat in Krishna Colony          flat  maa bhagwati residency   0.45
# 1     2 BHK Flat in Ashok Vihar          flat            apna enclave   0.50
# 2           2 BHK Flat in Sohna          flat  tulsiani easy in homes   0.40
#
#    price_per_sqft   area                    areaWithType  bedRoom  bathroom  \
# 0          5000.0  900.0  Carpet area: 900 (83.61 sq.m.)        2         2
# 1          7692.0  650.0  Carpet area: 650 (60.39 sq.m.)        2         2
# 2          6722.0  595.0  Carpet area: 595 (55.28 sq.m.)        2         2
#
#   balcony additionalRoom                             address  floorNum facing  \
# 0       1  not available    Krishna Colony, Gurgaon, Haryana       4.0   West
# 1       1  not available  46b, Ashok Vihar, Gurgaon, Haryana       1.0   West
# 2       3  not available             Sohna, Gurgaon, Haryana      12.0    NaN
#
#      agePossession                                    nearbyLocations  \
# 0  1 to 5 Year Old  ['Chintapurni Mandir', 'State bank ATM', 'Pear...
# 1     10+ Year Old  ['Chintapurni Mandir', 'Sheetla Mata Mandir', ...
# 2  0 to 1 Year Old  ['Huda City Metro', 'Golf Course extn road', '...
#
#                                          description  \
# 0  So with lift.Maa bhagwati residency is one of ...
# 1  Property situated on main road, railway statio...
# 2  This property is 15 km away from badshapur, gu...
#
#                                       furnishDetails  \
# 0  ['3 Fan', '4 Light', '1 Wardrobe', 'No AC', 'N...
# 1  ['3 Wardrobe', '4 Fan', '1 Exhaust Fan', '1 Ge...
# 2                                                NaN
#
#                                             features  \
# 0  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 1  ['Security / Fire Alarm', 'Maintenance Staff',...
# 2  ['Power Back-up', 'Feng Shui / Vaastu Complian...
#
#                                               rating
# 0  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 1  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 2  ['Environment4 out of 5', 'Safety4 out of 5', ...

# %%
house.head(5)
# Out:
#                                       property_name property_type  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon         house
# 1  5 Bedroom House for sale in Sector 21A Faridabad         house
# 2  10 Bedroom House for sale in Sushant Lok Phase 1         house
# 3    21 Bedroom House for sale in Sector 54 Gurgaon         house
# 4  12 Bedroom House for sale in Sushant Lok Phase 1         house
#
#             society  price  price_per_sqft    area  \
# 0  bptp visionnaire   5.25         20115.0  2610.0
# 1               NaN   5.70        105751.0   539.0
# 2               NaN   2.10         38251.0   549.0
# 3               NaN   5.00         43066.0  1161.0
# 4               NaN   3.00         53763.0   558.0
#
#                   areaWithType  bedRoom  bathroom balcony  \
# 0  Plot area 290(242.48 sq.m.)        5         4      3+
# 1   Plot area 539(50.07 sq.m.)        5         4       2
# 2       Plot area 61(51 sq.m.)       10        10      3+
# 3  Plot area 129(107.86 sq.m.)       21        21      3+
# 4    Plot area 62(51.84 sq.m.)       12        12      3+
#
#                        additionalRoom  \
# 0                        servant room
# 1  store room,pooja room,servant room
# 2                        servant room
# 3                        servant room
# 4                              others
#
#                                        address  floorNum      facing  \
# 0    29b, Sector 70A Gurgaon, Gurgaon, Haryana       3.0  North-East
# 1       Sector 21A Faridabad, Gurgaon, Haryana       2.0         NaN
# 2        Sushant Lok Phase 1, Gurgaon, Haryana       5.0        West
# 3          Sector 54 Gurgaon, Gurgaon, Haryana       5.0       North
# 4  1228, Sushant Lok Phase 1, Gurgaon, Haryana       5.0        West
#
#       agePossession                                    nearbyLocations  \
# 0   0 to 1 Year Old  ['Good Earth City Center 2', 'Kunskapsskolan I...
# 1  5 to 10 Year Old                                                NaN
# 2   0 to 1 Year Old  ['Sector 42-43 metro station', 'Huda city cent...
# 3   1 to 5 Year Old  ['Sector 53-54 metro station', 'Sector 54 chow...
# 4   Within 6 months  ['Sector 42-43 metro station', 'Huda city cent...
#
#                                          description  \
# 0  Do you wish to buy an independent house in sec...
# 1  Hi, we have an independent house/villa availab...
# 2  Monthly rental income is rs1,40,000/- Best opt...
# 3  129 sq yd plot size. 5 floors built up , fully...
# 4  Best for investment purpose. Fully furnished b...
#
#                                       furnishDetails  \
# 0  ['1 Wardrobe', '1 Fan', '1 Exhaust Fan', '1 Ge...
# 1  ['1 Water Purifier', '5 Fan', '1 Exhaust Fan',...
# 2  ['10 Bed', '3 Fan', '10 Geyser', '2 Light', 'N...
# 3  ['1 Water Purifier', '21 Fan', '1 Fridge', '1 ...
# 4  ['1 Water Purifier', '1 Fridge', '12 Fan', '1 ...
#
#                                             features  \
# 0  ['Feng Shui / Vaastu Compliant', 'Private Gard...
# 1  ['Private Garden / Terrace', 'Park', 'Visitor ...
# 2  ['Maintenance Staff', 'Water Storage', 'Visito...
# 3  ['Feng Shui / Vaastu Compliant', 'Private Gard...
# 4  ['Maintenance Staff', 'Water Storage', 'Visito...
#
#                                               rating
# 0  ['Environment5 out of 5', 'Lifestyle4 out of 5...
# 1                                                NaN
# 2  ['Environment5 out of 5', 'Lifestyle5 out of 5...
# 3  ['Environment4 out of 5', 'Lifestyle5 out of 5...
# 4  ['Environment5 out of 5', 'Lifestyle5 out of 5...

# %%
flats.columns
# Out:
# Index(['property_name', 'property_type', 'society', 'price', 'price_per_sqft',
#        'area', 'areaWithType', 'bedRoom', 'bathroom', 'balcony',
#        'additionalRoom', 'address', 'floorNum', 'facing', 'agePossession',
#        'nearbyLocations', 'description', 'furnishDetails', 'features',
#        'rating'],
#       dtype='object')

# %%
house.columns
# Out:
# Index(['property_name', 'property_type', 'society', 'price', 'price_per_sqft',
#        'area', 'areaWithType', 'bedRoom', 'bathroom', 'balcony',
#        'additionalRoom', 'address', 'floorNum', 'facing', 'agePossession',
#        'nearbyLocations', 'description', 'furnishDetails', 'features',
#        'rating'],
#       dtype='object')

# %%
flats.columns==house.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True])

# %%
df=pd.concat([flats,house],ignore_index=True)

# %%
df.sample(df.shape[0]).shape
# Out:
# (3961, 20)

# %%
df.shape
# Out:
# (3961, 20)

# %%
df=df.sample(df.shape[0],ignore_index=True)

# %%
df.head()
# Out:
#                                     property_name property_type  \
# 0  4 Bedroom House for sale in Sector 109 Gurgaon         house
# 1                2 BHK Flat in Sector 107 Gurgaon          flat
# 2                4 BHK Flat in Sector 103 Gurgaon          flat
# 3                             2 BHK Flat in Sohna          flat
# 4                             2 BHK Flat in Sohna          flat
#
#                                society  price  price_per_sqft    area  \
# 0  international city by sobha phase 1   5.50         21605.0  2546.0
# 1            signature global solera 2   0.50          8928.0   560.0
# 2                                  NaN   2.14          7443.0  2875.0
# 3                                  NaN   0.73          5752.0  1269.0
# 4                                  NaN   0.29          3970.0   730.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0                        Plot area 270(225.75 sq.m.)        4         4
# 1                     Carpet area: 560 (52.03 sq.m.)        2         2
# 2  Super Built up area 2875(267.1 sq.m.)Carpet ar...        4         6
# 3             Super Built up area 1269(117.89 sq.m.)        2         2
# 4  Built Up area: 743 (69.03 sq.m.)Carpet area: 5...        2         2
#
#   balcony additionalRoom                                      address  \
# 0      3+   servant room         Sector 109 Gurgaon, Gurgaon, Haryana
# 1       2  not available         Sector 107 Gurgaon, Gurgaon, Haryana
# 2      3+   Servant Room  G3-74, Sector 103 Gurgaon, Gurgaon, Haryana
# 3       3     Pooja Room                0001, Sohna, Gurgaon, Haryana
# 4       1  not available               Sohna, Sohna, Gurgaon, Haryana
#
#    floorNum      facing    agePossession  \
# 0       2.0  North-East  0 to 1 Year Old
# 1      13.0         NaN  0 to 1 Year Old
# 2       7.0        East  1 to 5 Year Old
# 3       9.0  North-East  1 to 5 Year Old
# 4       4.0         NaN        undefined
#
#                                      nearbyLocations  \
# 0  ['Dwarka sector 21 metro station', 'Pacific D2...
# 1      ['Dwarka Expressway', 'Delhi', 'IGI Airport']
# 2  ['Gurgaon Dreamz Mall', 'HUDA Market, Sector 1...
# 3  ['Global City Centre', 'Sohna Road', 'Damdama ...
# 4  ['The roadside cafe', 'GD Goenka Mess', 'ROyal...
#
#                                          description  \
# 0  A well maintained 270 sqyd villa with basement...
# 1  Located in the popular residential address of ...
# 2  Indiabulls centrum park is one of the most pop...
# 3  Eldeco accolade in sohna, gurgaon is a ready-T...
# 4  Best in class property available at sohna loca...
#
#                                       furnishDetails  \
# 0  ['1 Fan', '1 Exhaust Fan', '1 Geyser', '1 Ligh...
# 1  ['3 Fan', '1 Exhaust Fan', '5 Light', '1 Modul...
# 2  ['1 Exhaust Fan', '10 Light', 'No AC', 'No Bed...
# 3                                                NaN
# 4                                                NaN
#
#                                             features  \
# 0  ['Maintenance Staff', 'Swimming Pool', 'Water ...
# 1                                ['Lift(s)', 'Park']
# 2  ['Centrally Air Conditioned', 'Water purifier'...
# 3  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 4                                                NaN
#
#                                               rating
# 0  ['Environment5 out of 5', 'Lifestyle4 out of 5...
# 1  ['Environment3 out of 5', 'Lifestyle2 out of 5...
# 2  ['Green Area5 out of 5', 'Construction4 out of...
# 3  ['Green Area5 out of 5', 'Construction4.5 out ...
# 4  ['Green Area4 out of 5', 'Amenities4 out of 5'...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3961 entries, 0 to 3960
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    3961 non-null   object
#  1   property_type    3961 non-null   object
#  2   society          1690 non-null   object
#  3   price            3941 non-null   float64
#  4   price_per_sqft   3941 non-null   float64
#  5   area             3941 non-null   float64
#  6   areaWithType     3961 non-null   object
#  7   bedRoom          3961 non-null   int64
#  8   bathroom         3961 non-null   int64
#  9   balcony          3961 non-null   object
#  10  additionalRoom   3961 non-null   object
#  11  address          3950 non-null   object
#  12  floorNum         3940 non-null   float64
#  13  facing           2784 non-null   object
#  14  agePossession    3960 non-null   object
#  15  nearbyLocations  3754 non-null   object
#  16  description      3961 non-null   object
#  17  furnishDetails   2929 non-null   object
#  18  features         3252 non-null   object
#  19  rating           3511 non-null   object
# dtypes: float64(4), int64(2), object(14)
# memory usage: 619.0+ KB

# %%
df.to_csv('gurgaon_properties.csv',index=False)
